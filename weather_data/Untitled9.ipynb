# %%
import pandas as pd
df = pd.read_csv('weather.csv')
df
# Out:
#      outlook  temperature humidity  windy play
# 0   overcast           32     high  False  yes
# 1   overcast           34   normal   True  yes
# 2   overcast           66     high   True  yes
# 3   overcast           78   normal  False  yes
# 4      rainy           54     high  False  yes
# 5      rainy           63   normal  False  yes
# 6      rainy           12   normal   True   no
# 7      rainy           45   normal  False  yes
# 8      rainy           23     high   True   no
# 9      sunny           73     high  False   no
# 10     sunny           98     high   True   no
# 11     sunny           11     high  False   no
# 12     sunny           10   normal  False  yes
# 13     sunny           50   normal   True  yes

# %%
df.pivot(index='temperature',columns='humidity',values='windy')
# Out:
# humidity      high normal
# temperature
# 10             NaN  False
# 11           False    NaN
# 12             NaN   True
# 23            True    NaN
# 32           False    NaN
# 34             NaN   True
# 45             NaN  False
# 50             NaN   True
# 54           False    NaN
# 63             NaN  False
# 66            True    NaN
# 73           False    NaN
# 78             NaN  False
# 98            True    NaN

# %%
import matplotlib.pyplot as plt
a = [1,2,3,4,5,6,7]
b = [12,32,45,43,21,67,90]

plt.xlabel('temprature')
plt.ylabel('day')
plt.title('weather')
plt.plot(a,b,color='red',linewidth=1,linestyle='dotted')

# %%
plt.plot(x,y,':b+',linewidth=1)

# %%
plt.plot(x,y,':b*',linewidth=1,markersize=9,alpha=0.2)

# %%
import matplotlib.pyplot as plt
a = [1,2,3,4,5,6,7]
b = [12,32,45,43,21,67,90]
c = [23,44,33,11,96,67,78]
d = [98,25,57,51,84,14,9]
plt.xlabel('temprature')
plt.ylabel('day')
plt.title('weather')
plt.plot(a,b,color='blue',linewidth=1,linestyle='dotted' ,label='max')
plt.plot(a,c,color='red',linewidth=1,linestyle='dotted',label='min')
plt.plot(a,d,color='green',linewidth=1,linestyle='dotted',label='avg')
plt.legend(loc='best',shadow=True)
